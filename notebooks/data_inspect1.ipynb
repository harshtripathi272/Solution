# %%
import pandas as pd
import numpy as np

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.2

# %%
df=pd.read_excel("../public_emdat_custom_request_2026-03-19_0f2d7d02-f2fb-4c6c-a80b-fd916cc22658.xlsx")

df_2=pd.read_excel("../HIV_Sentinel_Surveillance_n.xls")

# %%
df_2.shape
# Out:
# (35, 42)

# %%
df_2.sample()
# Out:
#      States/UTs  SMM_2005  SMM_2006  SMM_2007  SMM_2009  SMM_2011  LDT_2006  \
# 32  Uttarakhand       NaN       NaN       NaN       NaN       NaN       NaN
#
#     LDT_2007  LDT_2009  LDT_2011  ...  FSW_2007  FSW_2008-09  FSW_2010-11  \
# 32       NaN       NaN       NaN  ...       NaN          NaN         0.44
#
#     ANC_2003  ANC_2004  ANC_2005  ANC_2006  ANC_2007  ANC_2008-09  ANC_2010-11
# 32      0.06       0.0       0.0      0.11      0.06         0.22         0.25
#
# [1 rows x 42 columns]

# %%
df_2.isnull().sum()
# Out:
# States/UTs      0
# SMM_2005       33
# SMM_2006       32
# SMM_2007       31
# SMM_2009       28
# SMM_2011       23
# LDT_2006       30
# LDT_2007       31
# LDT_2009       32
# LDT_2011       25
# TG_2006        33
# TG_2007        33
# TG_2009        33
# TG_2011        32
# IDU_2003       23
# IDU_2004       21
# IDU_2005       20
# IDU_2006       12
# IDU_2007       13
# IDU_2008-09    11
# IDU_2010-11     7
# MSM_2003       25
# MSM_2004       21
# MSM_2005       21
# MSM_2006       16
# MSM_2007       15
# MSM_2008-09    15
# MSM_2010-11    11
# FSW_2003       17
# FSW_2004       14
# FSW_2005       12
# FSW_2006        8
# FSW_2007        9
# FSW_2008-09     9
# FSW_2010-11     5
# ANC_2003        0
# ANC_2004        0
# ANC_2005        0
# ANC_2006        0
# ANC_2007        0
# ANC_2008-09     0
# ANC_2010-11     0
# dtype: int64

# %%
df_2.columns
# Out:
# Index(['States/UTs', 'SMM_2005', 'SMM_2006', 'SMM_2007', 'SMM_2009',
#        'SMM_2011', 'LDT_2006', 'LDT_2007', 'LDT_2009', 'LDT_2011', 'TG_2006',
#        'TG_2007', 'TG_2009', 'TG_2011', 'IDU_2003', 'IDU_2004', 'IDU_2005',
#        'IDU_2006', 'IDU_2007', 'IDU_2008-09', 'IDU_2010-11', 'MSM_2003',
#        'MSM_2004', 'MSM_2005', 'MSM_2006', 'MSM_2007', 'MSM_2008-09',
#        'MSM_2010-11', 'FSW_2003', 'FSW_2004', 'FSW_2005', 'FSW_2006',
#        'FSW_2007', 'FSW_2008-09', 'FSW_2010-11', 'ANC_2003', 'ANC_2004',
#        'ANC_2005', 'ANC_2006', 'ANC_2007', 'ANC_2008-09', 'ANC_2010-11'],
#       dtype='object')

# %%
df["Total Affected"].isnull().sum()
# Out:
# 1361
